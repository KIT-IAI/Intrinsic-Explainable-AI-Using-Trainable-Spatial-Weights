# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
opsd = pd.read_csv('opsd.csv', header=[0, 1], index_col=0)
opsd.index = pd.to_datetime(opsd.index).tz_localize(None)

# %%
opsd.loc[:, ('de_transnetbw', 'wind')].rolling('360d').max().plot()
# Out:
# <Axes: xlabel='utc_timestamp'>
